# %%
#importing required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
page4=requests.get('https://www.flipkart.com/search?q=sunglasses&sid=26x&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sunglasses%7CSunglasses&requestId=4a2bc891-b447-4354-9659-5405f1afbe25&as-searchtext=sunglas')

# %%
page4.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %%
soup=BeautifulSoup(page4.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
Brands_list=[]
product_list=[]
price_list=[]
Discount=[]

# %%
#Lets extract the all the brnads from flipkart sunglasses
brands=soup.find_all('img',class_='_2r_T1I')
brands[0:100]
# Out:
# [<img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
#  <img alt="" class="_2r_T1I" src=""/>,
# ...

# %%
#So we need to run loops

for i in brands:
    
    full_brands=''
    for j in i.find_all('b'):
        full_brands=full_brands+''+j.get_img()
        print(full_brands)
        job_titles.append(full_brands)

# %%
print(brands)
# Out:
# [<img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt="" class="_2r_T1I" src=""/>, <img alt=
# ...

# %%
#Lets extarct the products
product=soup.find_all('div',class_='_2WkVRV')
product[0:100]
# Out:
# [<div class="_2WkVRV">Royal Son</div>,
#  <div class="_2WkVRV">Gansta</div>,
#  <div class="_2WkVRV">FDA COLLECTION</div>,
#  <div class="_2WkVRV">FDA COLLECTION</div>,
#  <div class="_2WkVRV">Trendy Glasses</div>,
#  <div class="_2WkVRV">Rozzetta Craft</div>,
#  <div class="_2WkVRV">Phenomenal</div>,
#  <div class="_2WkVRV">Royal Son</div>,
#  <div class="_2WkVRV">FDA COLLECTION</div>,
#  <div class="_2WkVRV">ROZZETTA CRAFT</div>,
#  <div class="_2WkVRV">shah collections</div>,
#  <div class="_2WkVRV">Royal Son</div>,
#  <div class="_2WkVRV">JOHAENA</div>,
#  <div class="_2WkVRV">Dannilo</div>,
#  <div class="_2WkVRV">Phenomenal</div>,
#  <div class="_2WkVRV">Gansta</div>,
#  <div class="_2WkVRV">ROZZETTA CRAFT</div>,
#  <div class="_2WkVRV">Fastrack</div>,
#  <div class="_2WkVRV">Fastrack</div>,
#  <div class="_2WkVRV">Singco India</div>,
#  <div class="_2WkVRV">Winsome</div>,
#  <div class="_2WkVRV">Riffko</div>,
#  <div class="_2WkVRV">Collet</div>,
# ...

# %%
for i in product:
    product_list.append(i.get_text().replace('\n',' '))
    product_list[0:100]

# %%
print(product)
# Out:
# [<div class="_2WkVRV">Royal Son</div>, <div class="_2WkVRV">Gansta</div>, <div class="_2WkVRV">FDA COLLECTION</div>, <div class="_2WkVRV">FDA COLLECTION</div>, <div class="_2WkVRV">Trendy Glasses</div>, <div class="_2WkVRV">Rozzetta Craft</div>, <div class="_2WkVRV">Phenomenal</div>, <div class="_2WkVRV">Royal Son</div>, <div class="_2WkVRV">FDA COLLECTION</div>, <div class="_2WkVRV">ROZZETTA CRAFT</div>, <div class="_2WkVRV">shah collections</div>, <div class="_2WkVRV">Royal Son</div>, <div class="_2WkVRV">JOHAENA</div>, <div class="_2WkVRV">Dannilo</div>, <div class="_2WkVRV">Phenomenal</div>, <div class="_2WkVRV">Gansta</div>, <div class="_2WkVRV">ROZZETTA CRAFT</div>, <div class="_2WkVRV">Fastrack</div>, <div class="_2WkVRV">Fastrack</div>, <div class="_2WkVRV">Singco India</div>, <div class="_2WkVRV">Winsome</div>, <div class="_2WkVRV">Riffko</div>, <div class="_2WkVRV">Collet</div>, <div class="_2WkVRV">Royal Son</div>, <div class="_2WkVRV">funglasses</div>, <div class="_2WkVRV
# ...

# %%
#Lets extract the price
price=soup.find_all('div',class_='_30jeq3')
price[0:100]
# Out:
# [<div class="_30jeq3">₹224</div>,
#  <div class="_30jeq3">₹195</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹188</div>,
#  <div class="_30jeq3">₹224</div>,
#  <div class="_30jeq3">₹398</div>,
#  <div class="_30jeq3">₹379</div>,
#  <div class="_30jeq3">₹615</div>,
#  <div class="_30jeq3">₹161</div>,
#  <div class="_30jeq3">₹449</div>,
#  <div class="_30jeq3">₹331</div>,
#  <div class="_30jeq3">₹189</div>,
#  <div class="_30jeq3">₹160</div>,
#  <div class="_30jeq3">₹198</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹404</div>,
#  <div class="_30jeq3">₹674</div>,
#  <div class="_30jeq3">₹519</div>,
#  <div class="_30jeq3">₹208</div>,
#  <div class="_30jeq3">₹172</div>,
#  <div class="_30jeq3">₹189</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹175</div>,
#  <div class="_30jeq3">₹161</div>,
#  <div class="_30jeq3">₹242</div>,
#  <div class="_30jeq3">₹175</div>,
# ...

# %%
for i in price:
    price_list.append(i.text)
    price_list[0:100]

# %%
print(price)
# Out:
# [<div class="_30jeq3">₹224</div>, <div class="_30jeq3">₹195</div>, <div class="_30jeq3">₹199</div>, <div class="_30jeq3">₹188</div>, <div class="_30jeq3">₹224</div>, <div class="_30jeq3">₹398</div>, <div class="_30jeq3">₹379</div>, <div class="_30jeq3">₹615</div>, <div class="_30jeq3">₹161</div>, <div class="_30jeq3">₹449</div>, <div class="_30jeq3">₹331</div>, <div class="_30jeq3">₹189</div>, <div class="_30jeq3">₹160</div>, <div class="_30jeq3">₹198</div>, <div class="_30jeq3">₹399</div>, <div class="_30jeq3">₹199</div>, <div class="_30jeq3">₹404</div>, <div class="_30jeq3">₹674</div>, <div class="_30jeq3">₹519</div>, <div class="_30jeq3">₹208</div>, <div class="_30jeq3">₹172</div>, <div class="_30jeq3">₹189</div>, <div class="_30jeq3">₹199</div>, <div class="_30jeq3">₹175</div>, <div class="_30jeq3">₹161</div>, <div class="_30jeq3">₹242</div>, <div class="_30jeq3">₹175</div>, <div class="_30jeq3">₹255</div>, <div class="_30jeq3">₹201</div>, <div class="_30jeq3">₹309</div>, <div cl
# ...

# %%
#lets extract the discount data
discount=soup.find_all('div',class_='_3Ay6Sb')
discount[0:100]
# Out:
# [<div class="_3Ay6Sb"><span>82% off</span></div>,
#  <div class="_3Ay6Sb"><span>80% off</span></div>,
#  <div class="_3Ay6Sb"><span>84% off</span></div>,
#  <div class="_3Ay6Sb"><span>87% off</span></div>,
#  <div class="_3Ay6Sb"><span>82% off</span></div>,
#  <div class="_3Ay6Sb"><span>73% off</span></div>,
#  <div class="_3Ay6Sb"><span>81% off</span></div>,
#  <div class="_3Ay6Sb"><span>69% off</span></div>,
#  <div class="_3Ay6Sb"><span>83% off</span></div>,
#  <div class="_3Ay6Sb"><span>79% off</span></div>,
#  <div class="_3Ay6Sb"><span>80% off</span></div>,
#  <div class="_3Ay6Sb"><span>81% off</span></div>,
#  <div class="_3Ay6Sb"><span>87% off</span></div>,
#  <div class="_3Ay6Sb"><span>83% off</span></div>,
#  <div class="_3Ay6Sb"><span>80% off</span></div>,
#  <div class="_3Ay6Sb"><span>84% off</span></div>,
#  <div class="_3Ay6Sb"><span>79% off</span></div>,
#  <div class="_3Ay6Sb"><span>25% off</span></div>,
#  <div class="_3Ay6Sb"><span>35% off</span></div>,
# ...

# %%
print(discount)
# Out:
# [<div class="_3Ay6Sb"><span>82% off</span></div>, <div class="_3Ay6Sb"><span>80% off</span></div>, <div class="_3Ay6Sb"><span>84% off</span></div>, <div class="_3Ay6Sb"><span>87% off</span></div>, <div class="_3Ay6Sb"><span>82% off</span></div>, <div class="_3Ay6Sb"><span>73% off</span></div>, <div class="_3Ay6Sb"><span>81% off</span></div>, <div class="_3Ay6Sb"><span>69% off</span></div>, <div class="_3Ay6Sb"><span>83% off</span></div>, <div class="_3Ay6Sb"><span>79% off</span></div>, <div class="_3Ay6Sb"><span>80% off</span></div>, <div class="_3Ay6Sb"><span>81% off</span></div>, <div class="_3Ay6Sb"><span>87% off</span></div>, <div class="_3Ay6Sb"><span>83% off</span></div>, <div class="_3Ay6Sb"><span>80% off</span></div>, <div class="_3Ay6Sb"><span>84% off</span></div>, <div class="_3Ay6Sb"><span>79% off</span></div>, <div class="_3Ay6Sb"><span>25% off</span></div>, <div class="_3Ay6Sb"><span>35% off</span></div>, <div class="_3Ay6Sb"><span>79% off</span></div>, <div class="_3Ay6
# ...

# %%
print(len(brands),len(product_list),len(price_list),len(discount))
# Out:
# 40 40 45 90

# %%
import pandas as pd
Brands=pd.DataFrame({})
Brands['brands']=brands[0:10]
Brands['product_list']=product_list[0:10]
Brands['price']=price_list[0:10]
Brands['discount']=discount[0:10]

# %%
Brands
# Out:
#                                  brands    product_list price  \
# 0  <img alt="" class="_2r_T1I" src=""/>       Royal Son  ₹224
# 1  <img alt="" class="_2r_T1I" src=""/>          Gansta  ₹195
# 2  <img alt="" class="_2r_T1I" src=""/>  FDA COLLECTION  ₹199
# 3  <img alt="" class="_2r_T1I" src=""/>  FDA COLLECTION  ₹188
# 4  <img alt="" class="_2r_T1I" src=""/>  Trendy Glasses  ₹224
# 5  <img alt="" class="_2r_T1I" src=""/>  Rozzetta Craft  ₹398
# 6  <img alt="" class="_2r_T1I" src=""/>      Phenomenal  ₹379
# 7  <img alt="" class="_2r_T1I" src=""/>       Royal Son  ₹615
# 8  <img alt="" class="_2r_T1I" src=""/>  FDA COLLECTION  ₹161
# 9  <img alt="" class="_2r_T1I" src=""/>  ROZZETTA CRAFT  ₹449
#
#                                           discount
# 0  <div class="_3Ay6Sb"><span>82% off</span></div>
# 1  <div class="_3Ay6Sb"><span>80% off</span></div>
# 2  <div class="_3Ay6Sb"><span>84% off</span></div>
# 3  <div class="_3Ay6Sb"><span>87% off</span></div>
# ...

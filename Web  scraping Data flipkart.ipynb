# %%
#importing required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
page6=requests.get('https://www.flipkart.com/search?q=sneakers&sid=osp%2Ccil%2Ce1f&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=sneakers%7CMen%27s+Casual+Shoes&requestId=ace29ea7-2680-44c8-a563-4c09d5832238&as-searchtext=sneak')

# %%
page6.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %%
soup=BeautifulSoup(page6.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e0eee8.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
Brands_list=[]
product_list=[]
price_list=[]
Discount=[]

# %%
#Lets  extarct the brands
brands=soup.find_all('div',class_='_2WkVRV')
brands[0:100]
# Out:
# [<div class="_2WkVRV">Anover</div>,
#  <div class="_2WkVRV">BUCIK</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">Shoes Bank</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">World Wear Footwear</div>,
#  <div class="_2WkVRV">DIGITRENDZZ</div>,
#  <div class="_2WkVRV">Robbie jones</div>,
#  <div class="_2WkVRV">Deny Brown</div>,
#  <div class="_2WkVRV">GANPATI TRADERS</div>,
#  <div class="_2WkVRV">Puma</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">Red Rose</div>,
#  <div class="_2WkVRV">Oricum</div>,
#  <div class="_2WkVRV">Black Bottom</div>,
#  <div class="_2WkVRV">Chevit</div>,
#  <div class="_2WkVRV">Hotstyle</div>,
#  <div class="_2WkVRV">D-SNEAKERZ</div>,
#  <div class="_2WkVRV">Kizaar</div>,
#  <div class="_2WkVRV">Stinson</div>,
#  <div class="_2WkVRV">Essence</div>,
#  <div class="_2WkVRV">Essence</div>,
#  <div class="_2WkVRV">FAUSTO</div>,
# ...

# %%
#So we need to run loops

for i in brands:
    
    full_brands=''
    for j in i.find_all('b'):
        full_brands=full_brands+''+j.get_div()
        print(full_brands)
        job_titles.append(full_brands)

# %%
print(brands)
# Out:
# [<div class="_2WkVRV">Anover</div>, <div class="_2WkVRV">BUCIK</div>, <div class="_2WkVRV">Chevit</div>, <div class="_2WkVRV">Chevit</div>, <div class="_2WkVRV">Shoes Bank</div>, <div class="_2WkVRV">Chevit</div>, <div class="_2WkVRV">World Wear Footwear</div>, <div class="_2WkVRV">DIGITRENDZZ</div>, <div class="_2WkVRV">Robbie jones</div>, <div class="_2WkVRV">Deny Brown</div>, <div class="_2WkVRV">GANPATI TRADERS</div>, <div class="_2WkVRV">Puma</div>, <div class="_2WkVRV">Chevit</div>, <div class="_2WkVRV">Red Rose</div>, <div class="_2WkVRV">Oricum</div>, <div class="_2WkVRV">Black Bottom</div>, <div class="_2WkVRV">Chevit</div>, <div class="_2WkVRV">Hotstyle</div>, <div class="_2WkVRV">D-SNEAKERZ</div>, <div class="_2WkVRV">Kizaar</div>, <div class="_2WkVRV">Stinson</div>, <div class="_2WkVRV">Essence</div>, <div class="_2WkVRV">Essence</div>, <div class="_2WkVRV">FAUSTO</div>, <div class="_2WkVRV">Rockfield</div>, <div class="_2WkVRV">Oricum</div>, <div class="_2WkVRV">Chevit</
# ...

# %%
#Lets extarct the products
product=soup.find_all('a',class_='IRpwTa')
product[0:100]
# Out:
# [<a class="IRpwTa" href="/anover-sneakers-men/p/itm16eb2c30794f3?pid=SHOFT8ZY8HWTYBGF&amp;lid=LSTSHOFT8ZY8HWTYBGFBJBMWB&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;fm=organic&amp;iid=en_l%2F2IjYm0NpRLQ0SfB18jcCAPhPlO%2FJjxwNkImYMJpUyFzXvSMPPVtd4sekPg0611vqWqSfgXlM7VIoVkuuuq4A%3D%3D&amp;ssid=be07t9o3o00000001608314110337&amp;qH=a1743c0d39461290" rel="noopener noreferrer" target="_blank" title="Sneakers For Men">Sneakers For Men</a>,
# ...

# %%
for i in product:
    product_list.append(i.get_text().replace('\n',' '))
    product_list[0:100]

# %%
print(product)
# Out:
# [<a class="IRpwTa" href="/anover-sneakers-men/p/itm16eb2c30794f3?pid=SHOFT8ZY8HWTYBGF&amp;lid=LSTSHOFT8ZY8HWTYBGFBJBMWB&amp;marketplace=FLIPKART&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;fm=organic&amp;iid=en_l%2F2IjYm0NpRLQ0SfB18jcCAPhPlO%2FJjxwNkImYMJpUyFzXvSMPPVtd4sekPg0611vqWqSfgXlM7VIoVkuuuq4A%3D%3D&amp;ssid=be07t9o3o00000001608314110337&amp;qH=a1743c0d39461290" rel="noopener noreferrer" target="_blank" title="Sneakers For Men">Sneakers For Men</a>, <a class="IRpwTa _2-ICcC" href="/bucik-sneakers-men/p/itmdf60069607f46?pid=SHOFTC9QKFDSGXTM&amp;lid=LSTSHOFTC9QKFDSGXTMH9FMSD&amp;marketplace=FLIPKART&amp;srno=s_1_2&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;fm=organic&amp;iid=en_l%2F2IjYm0NpRLQ0SfB18jcCAPhPlO%2FJjxwNkImYMJpUx5ilAnIeBzl6XFfL02NmTSqFCKL%2Bhu0F78qnCe%2FGZsKg%3D%3D&amp;ssid=be07t9o3o0000000160831
# ...

# %%
#Lets extract the price
price=soup.find_all('div',class_='_30jeq3')
price[0:100]
# Out:
# [<div class="_30jeq3">₹398</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹579</div>,
#  <div class="_30jeq3">₹224</div>,
#  <div class="_30jeq3">₹349</div>,
#  <div class="_30jeq3">₹224</div>,
#  <div class="_30jeq3">₹240</div>,
#  <div class="_30jeq3">₹379</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹369</div>,
#  <div class="_30jeq3">₹199</div>,
#  <div class="_30jeq3">₹1,253</div>,
#  <div class="_30jeq3">₹224</div>,
#  <div class="_30jeq3">₹350</div>,
#  <div class="_30jeq3">₹419</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹359</div>,
#  <div class="_30jeq3">₹205</div>,
#  <div class="_30jeq3">₹370</div>,
#  <div class="_30jeq3">₹450</div>,
#  <div class="_30jeq3">₹829</div>,
#  <div class="_30jeq3">₹374</div>,
#  <div class="_30jeq3">₹374</div>,
#  <div class="_30jeq3">₹699</div>,
#  <div class="_30jeq3">₹399</div>,
#  <div class="_30jeq3">₹284</div>,
#  <div class="_30jeq3">₹224</div>,
# ...

# %%
for i in price:
    price_list.append(i.text)
    price_list[0:100]

# %%
print(price)
# Out:
# [<div class="_30jeq3">₹398</div>, <div class="_30jeq3">₹399</div>, <div class="_30jeq3">₹579</div>, <div class="_30jeq3">₹224</div>, <div class="_30jeq3">₹349</div>, <div class="_30jeq3">₹224</div>, <div class="_30jeq3">₹240</div>, <div class="_30jeq3">₹379</div>, <div class="_30jeq3">₹399</div>, <div class="_30jeq3">₹369</div>, <div class="_30jeq3">₹199</div>, <div class="_30jeq3">₹1,253</div>, <div class="_30jeq3">₹224</div>, <div class="_30jeq3">₹350</div>, <div class="_30jeq3">₹419</div>, <div class="_30jeq3">₹399</div>, <div class="_30jeq3">₹359</div>, <div class="_30jeq3">₹205</div>, <div class="_30jeq3">₹370</div>, <div class="_30jeq3">₹450</div>, <div class="_30jeq3">₹829</div>, <div class="_30jeq3">₹374</div>, <div class="_30jeq3">₹374</div>, <div class="_30jeq3">₹699</div>, <div class="_30jeq3">₹399</div>, <div class="_30jeq3">₹284</div>, <div class="_30jeq3">₹224</div>, <div class="_30jeq3">₹378</div>, <div class="_30jeq3">₹367</div>, <div class="_30jeq3">₹679</div>, <div 
# ...

# %%
#lets extract the discount data
discount=soup.find_all('div',class_='_3Ay6Sb')
discount[0:100]
# Out:
# [<div class="_3Ay6Sb"><span>60% off</span></div>,
#  <div class="_3Ay6Sb"><span>80% off</span></div>,
#  <div class="_3Ay6Sb"><span>70% off</span></div>,
#  <div class="_3Ay6Sb"><span>55% off</span></div>,
#  <div class="_3Ay6Sb"><span>65% off</span></div>,
#  <div class="_3Ay6Sb"><span>55% off</span></div>,
#  <div class="_3Ay6Sb"><span>51% off</span></div>,
#  <div class="_3Ay6Sb"><span>62% off</span></div>,
#  <div class="_3Ay6Sb"><span>60% off</span></div>,
#  <div class="_3Ay6Sb"><span>26% off</span></div>,
#  <div class="_3Ay6Sb"><span>60% off</span></div>,
#  <div class="_3Ay6Sb"><span>62% off</span></div>,
#  <div class="_3Ay6Sb"><span>55% off</span></div>,
#  <div class="_3Ay6Sb"><span>64% off</span></div>,
#  <div class="_3Ay6Sb"><span>58% off</span></div>,
#  <div class="_3Ay6Sb"><span>60% off</span></div>,
#  <div class="_3Ay6Sb"><span>64% off</span></div>,
#  <div class="_3Ay6Sb"><span>58% off</span></div>,
#  <div class="_3Ay6Sb"><span>43% off</span></div>,
# ...

# %%
print(discount)
# Out:
# [<div class="_3Ay6Sb"><span>60% off</span></div>, <div class="_3Ay6Sb"><span>80% off</span></div>, <div class="_3Ay6Sb"><span>70% off</span></div>, <div class="_3Ay6Sb"><span>55% off</span></div>, <div class="_3Ay6Sb"><span>65% off</span></div>, <div class="_3Ay6Sb"><span>55% off</span></div>, <div class="_3Ay6Sb"><span>51% off</span></div>, <div class="_3Ay6Sb"><span>62% off</span></div>, <div class="_3Ay6Sb"><span>60% off</span></div>, <div class="_3Ay6Sb"><span>26% off</span></div>, <div class="_3Ay6Sb"><span>60% off</span></div>, <div class="_3Ay6Sb"><span>62% off</span></div>, <div class="_3Ay6Sb"><span>55% off</span></div>, <div class="_3Ay6Sb"><span>64% off</span></div>, <div class="_3Ay6Sb"><span>58% off</span></div>, <div class="_3Ay6Sb"><span>60% off</span></div>, <div class="_3Ay6Sb"><span>64% off</span></div>, <div class="_3Ay6Sb"><span>58% off</span></div>, <div class="_3Ay6Sb"><span>43% off</span></div>, <div class="_3Ay6Sb"><span>54% off</span></div>, <div class="_3Ay6
# ...

# %%
print(len(brands),len(product_list),len(price_list),len(discount))
# Out:
# 40 40 45 44

# %%
import pandas as pd
Brands=pd.DataFrame({})
Brands['brands']=brands[0:10]
Brands['product_list']=product_list[0:10]
Brands['price']=price_list[0:10]
Brands['discount']=discount[0:10]

# %%
Brands
# Out:
#                                            brands  \
# 0               <div class="_2WkVRV">Anover</div>
# 1                <div class="_2WkVRV">BUCIK</div>
# 2               <div class="_2WkVRV">Chevit</div>
# 3               <div class="_2WkVRV">Chevit</div>
# 4           <div class="_2WkVRV">Shoes Bank</div>
# 5               <div class="_2WkVRV">Chevit</div>
# 6  <div class="_2WkVRV">World Wear Footwear</div>
# 7          <div class="_2WkVRV">DIGITRENDZZ</div>
# 8         <div class="_2WkVRV">Robbie jones</div>
# 9           <div class="_2WkVRV">Deny Brown</div>
#
#                                         product_list price  \
# 0                                   Sneakers For Men  ₹398
# 1                                   Sneakers For Men  ₹399
# 2  Combo Pack of 4 Casual Sneakers With Sneakers ...  ₹579
# 3  171 Smart Tan Lace-Ups Casuals for Men Sneaker...  ₹224
# 4     White Sneaker For Men's/Boy's Sneakers For Men  ₹349
# ...
